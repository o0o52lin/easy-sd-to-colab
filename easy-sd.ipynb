# %%
from google.colab import drive
drive.mount('/content/drive')
# !bash <(curl -sL https://raw.githubusercontent.com/o0o52lin/easy-sd-to-colab/main/easy-sd.sh) -l https://github.com/o0o52lin/easy-sd-to-colab -n template
